# %%
import pandas as pd

# %%
mydf = pd.read_json("JSON/web_dic.json")

# %%
mydf[mydf["make_name"] == "Ferrari"]
# Out:
#       make_name    model_name    body_type fuel_type  \
# 12501   Ferrari           360        Coupe  Gasoline
# 12502   Ferrari           360        Coupe  Gasoline
# 12503   Ferrari           360        Coupe  Gasoline
# 12504   Ferrari           360        Coupe  Gasoline
# 12505   Ferrari           360        Coupe  Gasoline
# ...         ...           ...          ...       ...
# 12717   Ferrari     Portofino  Convertible  Gasoline
# 12718   Ferrari     Portofino  Convertible  Gasoline
# 12719   Ferrari     Portofino  Convertible  Gasoline
# 12720   Ferrari  Superamerica  Convertible  Gasoline
# 12721   Ferrari  Superamerica  Convertible  Gasoline
#
#                          transmission  horsepower  engine_displacement  \
# 12501      Automatic Transmission (A)         400                 3600
# 12502      Automatic Transmission (A)         400                 3600
# 12503      Automatic Transmission (A)         400                 3600
# ...
